# %% [markdown]
# 1. # AVX512 Kaggle Environment

# %% [markdown]
# 1. Ensure that you got a machine with the Xeon CPU that supports avx512f SIMD instructions (look into the `flags` field).

# %%
# !cat /proc/cpuinfo

# %% [markdown]
# 2. Install all the necessary software.

# %%
# !apt-get install tmate magic-wormhole -y

# %% [markdown]
# 3. Prepare the encryption keys for the remote shell environment.

# %%
# !ssh-keygen -t rsa -N "" -C "tmate" -f "/root/.ssh/id_rsa"

# %% [markdown]
# 4. Start the remote shell environment in background.

# %%
# !tmate -S /tmp/tmate.sock new-session -d

# %% [markdown]
# 5. Get the SSH string to connect to the machine.

# %%
# !tmate -S /tmp/tmate.sock display -p \'#{tmate_ssh}\'

# %% [markdown]
# 6. Send your code from the `auca.space` server to the Kaggle machine with the `wormhole send <project directory name>` command. Receive the code on the Kaggle machine with the `wormhole receive` commad.

# %% [markdown]
# 7. Compile, run, debug...

# %% [markdown]
# 8. Download the image files with `scp` or `wormhole`. You may also use Visual Studio Code with the SSH Remote Plug-in.

# %% [markdown]
# 9. Clone your course private repository to the Kaggle or `auca.space` machine (where you have the final version of your code). Put the file `filters.impl.h.c` with all your changes into the path `project/task-01/` and `project/task-02` of your private repo. Commit and push. Submit the last commit ID to Canvas before the deadline.

# %% [markdown]
# 10. Ensure only to run and debug your programs on Kaggle. Do not use the service for development. Kaggle instances may stop after a period of inactivity (around 40 minutes). You will lose all your code on that machine in that case.
